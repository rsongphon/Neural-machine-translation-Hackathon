# %%
import os
import re
import pandas as pd

# %% [markdown]
# # Inspec Validation set

# %%
valfile_1_en = '/content/drive/MyDrive/NMT Hackathon/Dataset/ValidationSet/Valid1+2/dev.en'
valfile_1_th = '/content/drive/MyDrive/NMT Hackathon/Dataset/ValidationSet/Valid1+2/dev.th'
valfile_2_en = '/content/drive/MyDrive/NMT Hackathon/Dataset/ValidationSet/Valid1+2/dev2.en'
valfile_2_th = '/content/drive/MyDrive/NMT Hackathon/Dataset/ValidationSet/Valid1+2/dev2.th'

# %%
def file2liststring(filepath):
  with open(filepath, mode='rb') as file: 
      stringlist = file.readlines()
  return [re.sub('[\r\n]', '', text.decode('utf-8')) for text in stringlist]

# %%
'''
val1_en = {}
val1_string_en = []
val1_numline_en = 0
with open(valfile_1_en, mode='rb') as file: 
    val1_string_en = file.readlines()
    val1_numline_en = len(val1_string_en)

val1_string_en = [re.sub('[\r\n]', '', text.decode('utf-8')) for text in val1_string_en]
val1_en['raw_text'] = val1_string_en
val1_en['linecount'] = val1_numline_en
'''
# Out:
# "\nval1_en = {}\nval1_string_en = []\nval1_numline_en = 0\nwith open(valfile_1_en, mode='rb') as file: \n    val1_string_en = file.readlines()\n    val1_numline_en = len(val1_string_en)\n\nval1_string_en = [re.sub('[\r\n]', '', text.decode('utf-8')) for text in val1_string_en]\nval1_en['raw_text'] = val1_string_en\nval1_en['linecount'] = val1_numline_en\n"

# %%
val1_en_raw = file2liststring(valfile_1_en)
val1_th_raw = file2liststring(valfile_1_th)

# %%
val2_en_raw = file2liststring(valfile_2_en)
val2_th_raw = file2liststring(valfile_2_th)

# %%
val1_dict = {
              'source' : val1_en_raw,
              'target' : val1_th_raw
            }

val2_dict = {
              'source' : val2_en_raw,
              'target' : val2_th_raw
            }

# %%
val1 =  pd.DataFrame(val1_dict)
val2 =  pd.DataFrame(val2_dict)

# %%
val1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   source  1018 non-null   object
#  1   target  1018 non-null   object
# dtypes: object(2)
# memory usage: 16.0+ KB

# %%
val1.sample(20)
# Out:
#                                                  source  \
# 734   However, the cuts in guaranteed benefits for m...
# 409   He said that he had written most of the rest b...
# 77    According to officials, no injuries have been ...
# 906   On Friday, May 27, 2005, 9 trains on the New Y...
# 844   "The doctor asked him a couple of questions an...
# 276   However, Ingrid Rijniers is refusing to co-ope...
# 1000  The couple was returning from a poetry reading...
# 300   Richard Weber, M.S.M. (born June 9, 1959 in Ed...
# 32    According to the United States Geological Surv...
# 635   Heavy snow for parts of Northern England had a...
# 311   In what appeared to be a hostage situation end...
# 767   Brandon Backe, without a decision in his three...
# 478   "I am trying to set up high-level meetings in ...
# 740   Mr Darling was attending the launch of the pro...
# 204   The report, the product of a four-month invest...
# 703   Despite fines of up to $44,000 and 12 months i...
# ...

# %%
val2.sample(20)
# Out:
#                                                  source  \
# 1499        I'm titanium. I'm invincible. Amerika says.
# 342                                     I got a paddle.
# 739   But we're fugitives. We should just lay low ti...
# 1395                                              Yeah.
# 1631      I need to know that you'll take care of them.
# 322                                          - Dah. Ah.
# 127             I'm retiring next year. Did i tell you?
# 1081     (sighs) And, yeah, I was scared to start over.
# 1508  I was excited Brad asked me to be his partner ...
# 290     Did you hear what I just said? I'm sorry. What?
# 1001  I repeat, the impostor has been shot down... b...
# 151                                     -DO HOUSES FLY?
# 1529                       W- wait, what about college?
# 1565           Oh, and there's our furry family member.
# 1261  Maybe I'll have your willpower after being aro...
# 1270            Is there something you need to tell us?
# ...

# %% [markdown]
# # Inspect Nectec Corpus

# %%
nectecfile_1_en = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/LST_ENTH680K/lowercase/lang.en'
nectecfile_1_th = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/LST_ENTH680K/lowercase/lang.th'

# %%
nectec_en_raw = file2liststring(nectecfile_1_en)
nectec_th_raw = file2liststring(nectecfile_1_th)

# %%
nectec_en_raw[228663]
# Out:
# 'i would like some chef &apos;s special salad'

# %%
nectec_dict = {
              'source' : nectec_en_raw ,
              'target' : nectec_th_raw
            }

# %%
nectec_df =  pd.DataFrame(nectec_dict)

# %%
nectec_df.sample(20)
# Out:
#                                                    source  \
# 374858                be a success beyond all expectation
# 255322                      the shelf groans with books .
# 15863                   i forget to pick up the cleaning.
# 228663       i would like some chef &apos;s special salad
# 141224  i reminded you that i would come and get my sh...
# 364284             she has just recovered consciousness .
# 252028                                 reduction in wages
# 127235                                 can cars still run
# 306904  yeah, i saw him hoist his son up at the home p...
# 211179                                             engulf
# 545204                            and it's very efficient
# 361726                      the joint broke with a snap .
# 322809                                   not a few others
# 88897      i'm busy every day taking care of sick people.
# 65786   the collapse of the government left the countr...
# ...

# %%
nectec_df.iloc[[228663]]
# Out:
#                                               source                  target
# 228663  i would like some chef &apos;s special salad  ฉัน ต้องการ สลัด พิเศษ

# %%
#  &apos; = 's 'm 'd  เช่น &apos;s = 's

# %% [markdown]
# # Inpec Main Corpus

# %%
# Bible
biblefile_1_en = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/OPUS_BiTextCollections/Bible/bible-uedin.en-th.en'
biblefile_1_th = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/OPUS_BiTextCollections/Bible/bible-uedin.en-th.th'
bible_en_raw = file2liststring(biblefile_1_en)
bible_th_raw = file2liststring(biblefile_1_th)

bible_dict = {
              'source' : bible_en_raw ,
              'target' : bible_th_raw
            }
bible_df =  pd.DataFrame(bible_dict)

# %%
bible_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124386 entries, 0 to 124385
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   source  124386 non-null  object
#  1   target  124386 non-null  object
# dtypes: object(2)
# memory usage: 1.9+ MB

# %%
bible_df.sample(20)
# Out:
#                                                    source  \
# 22142   Prostitution, wine, and new wine take away und...
# 99326   And when the inhabitants of Gibeon heard what ...
# 29334   not in the way of service only when eyes are o...
# 34814   The families of the sons of Kohath shall encam...
# 12119   and the rest of the nations whom the great and...
# 3096    he is a leprous man. He is unclean. The priest...
# 7693    Saul said to David, "Behold, my elder daughter...
# 20541   Then I said, Ah Lord Yahweh! behold, my soul h...
# 112466  Thine habitation is in the midst of deceit; th...
# 113517  And with thee will I break in pieces the horse...
# 94773   Issachar is a strong ass couching down between...
# 23081   So will be the plague of the horse, of the mul...
# 19064   "How can I pardon you? Your children have fors...
# 2046    Yahweh came down on Mount Sinai, to the top of...
# 66062   One golden spoon of ten shekels, full of incense:
# ...

# %%
# GNOME
gnomefile_1_en = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/OPUS_BiTextCollections/GNOME/GNOME.en-th.en'
gnomefile_1_th = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/OPUS_BiTextCollections/GNOME/GNOME.en-th.th'
gnome_en_raw = file2liststring(gnomefile_1_en)
gnome_th_raw = file2liststring(gnomefile_1_th)

gnome_dict = {
              'source' : gnome_en_raw ,
              'target' : gnome_th_raw
            }
gnome_df =  pd.DataFrame(gnome_dict)

# %%
gnome_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   source  78 non-null     object
#  1   target  78 non-null     object
# dtypes: object(2)
# memory usage: 1.3+ KB

# %%
gnome_df.sample(20)
# Out:
#                                                source  \
# 24                               Selected application
# 30                         Start/stop event recording
# 25                                Selected accessible
# 56                                           Des_ktop
# 21                                    _Monitor Events
# 26                                             Source
# 28  Shows events as they occur from selected types...
# 66                                         Select All
# 36                                               Show
# 59                                          Hyperlink
# 10                               Highlight fill color
# 18                                    IPython Console
# 4         The default plugin layout for the top panel
# 71                                   Selected columns
# 16                                           Property
# 50                                             WIDGET
# ...

# %%
# JW300
JW300file_1_en = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/OPUS_BiTextCollections/JW300/jw300.en'
JW300file_1_th = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/OPUS_BiTextCollections/JW300/jw300.th'
JW300_en_raw = file2liststring(JW300file_1_en)
JW300_th_raw = file2liststring(JW300file_1_th)

JW300_dict = {
              'source' : JW300_en_raw ,
              'target' : JW300_th_raw
            }
JW300_df =  pd.DataFrame(JW300_dict)

# %%
JW300_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 818629 entries, 0 to 818628
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   source  818629 non-null  object
#  1   target  818629 non-null  object
# dtypes: object(2)
# memory usage: 12.5+ MB

# %%
JW300_df.isna().any()
# Out:
# False

# %%
JW300_df.sample(20)
# Out:
#                                                    source  \
# 160517               ‘ The 21st Century’s New Pathology ’
# 216356  Monitor your progress . Keep a journal , and m...
# 637145                                       [ Footnote ]
# 132290                                                  *
# 547990
# 277229  But how wise it is to be like those who have m...
# 811617  He was so moved that a surge of strong empathe...
# 815485  3 : 1 . ( a ) How is disobedience to parents v...
# 129543                             [ Picture on page 18 ]
# 280593  Any so - called Christian who promotes revolut...
# 454585  If we are God’s ministers , we will comport ou...
# 775314
# 407841  He no longer has the same freedom of movement ...
# 321933  “ Words cannot express the joy I felt when a w...
# 310658  Do you , like Elijah , have faith that Jehovah...
# 630807  The Witnesses started a Bible discussion and l...
# 526053  When they learned the truth of God’s Word , th...
# ...

# %% [markdown]
# # Inpec Clean Dataset

# %%
gnome_path = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/GNOME_dataset.csv'
lst_path = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/LST_Tokenize_Upper_Cleaned.csv'
qed_path = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/QED_Clean.csv'
tanzil_path = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/Tanzil_dataset.csv'
ubuntu_path = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/Ubuntu_dataset.csv'
bible_path = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/bible_dataset.csv'
jw300_path  = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/jw300.csv'
sub_path = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/sub_finallycleaned.csv'

# %%
# gnome
gnome_df = pd.read_csv(gnome_path)

# %%
gnome_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   en      74 non-null     object
#  1   th      74 non-null     object
# dtypes: object(2)
# memory usage: 1.3+ KB

# %%
gnome_df.head()
# Out:
#                                                en  \
# 0  Give your application an accessibility workout
# 1               Accerciser Accessibility Explorer
# 2  The default plugin layout for the bottom panel
# 3     The default plugin layout for the top panel
# 4  A list of plugins that are disabled by default
#
#                                              th
# 0    ช่วยพัฒนาสิ่งอำนวยความสะดวกในโปรแกรมของคุณ
# 1  Accerciser เครื่องมือสำรวจสิ่งอำนวยความสะดวก
# 2           การจัดวางปลั๊กอินสำหรับช่องด้านล่าง
# 3             การจัดวางปลั๊กอินสำหรับช่องด้านบน
# 4                 รายการปลั๊กอินที่ปิดโดยปริยาย

# %%
# lst
lst_df = pd.read_csv(lst_path)

# %%
lst_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 653137 entries, 0 to 653136
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   EN      653137 non-null  object
#  1   TH      653137 non-null  object
# dtypes: object(2)
# memory usage: 10.0+ MB

# %%
lst_df.head()
# Out:
#                                                   TH  \
# 0                      ขอบคุณ แต่ ฉัน ไม่ มี เวลา พอ
# 1  โอ้  คุณ รู้  เมื่อ ฉัน ตื่น ฉัน จะ ออก ไป เดิ...
# 2           หน้าที่ ของ ตำรวจ คือ การ ปกป้อง ประชาชน
# 3                  มัน เป็น ความ โอหัง ของ เพศ หญิง
# 4                              โปรด คอย ดู อย่า เผลอ
#
#                                                   EN
# 0             Thank you but I don't have enough time
# 1  Oh you know when I get up I usually do my stre...
# 2    The duty of a policeman is to safeguard people.
# 3                                It's female vanity.
# 4                       Please keep a sharp lookout.

# %%
columns_titles = ["EN","TH"]
lst_df = lst_df.reindex(columns=columns_titles)

# %%
lst_df = lst_df.rename(columns={'EN': 'en', 'TH': 'th'})

# %%
lst_df.head()
# Out:
#                                                   en  \
# 0             Thank you but I don't have enough time
# 1  Oh you know when I get up I usually do my stre...
# 2    The duty of a policeman is to safeguard people.
# 3                                It's female vanity.
# 4                       Please keep a sharp lookout.
#
#                                                   th
# 0                      ขอบคุณ แต่ ฉัน ไม่ มี เวลา พอ
# 1  โอ้  คุณ รู้  เมื่อ ฉัน ตื่น ฉัน จะ ออก ไป เดิ...
# 2           หน้าที่ ของ ตำรวจ คือ การ ปกป้อง ประชาชน
# 3                  มัน เป็น ความ โอหัง ของ เพศ หญิง
# 4                              โปรด คอย ดู อย่า เผลอ

# %%
def process(my_str):
    l = my_str.replace(' ','')
    return pd.Series(l)

# %%
lst_df[['th']] = lst_df["th"].apply(process)

# %%
lst_df.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/LST_Tokenize_Upper_Cleaned_reform.csv',index = False)

# %%
# QED
qed_df = pd.read_csv(qed_path)

# %%
qed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40155 entries, 0 to 40154
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   th      40155 non-null  object
#  1   en      40155 non-null  object
# dtypes: object(2)
# memory usage: 627.5+ KB

# %%
qed_df
# Out:
#                                               th  \
# 0      นี่คือปัญหาข้อเดิมที่เราทำในวิดีโอที่แล้ว
# 1                        คุณลืมคำถามที่แล้วไปได้
# 2                            คุณทิ้งทั้งหมดนี่ไป
# 3                                ลองคิดแบบนี้กัน
# 4              นั่นคือสิ่งที่เจ้านี่ตรงนี้บอกเรา
# ...                                          ...
# 40150            แต่ผมยังไม่รู้ว่าสิ่งนี้คืออะไร
# 40151                            ผมอยากพูดให้ชัด
# 40152  และผมไม่ต้องสมมุติสิ่งนี้เพื่อให้ได้มันมา
# 40153   ดังนั้นไม่มีทางที่บทพิสูจน์นี้จะวนตัวเอง
# 40154              ผมผิดเองที่ไม่ได้อธิบายให้ชัด
#
#                                                       en
# 0      This is the same problem that we had in the la...
# 1           So you could ignore the question right here.
# 2                            You can ignore all of this.
# 3                         So let's think about this way.
# 4                  That's what this right here tells us.
# ...

# %%
columns_titles = ["en","th"]
qed_df = qed_df.reindex(columns=columns_titles)

# %%
qed_df
# Out:
#                                                       en  \
# 0      This is the same problem that we had in the la...
# 1           So you could ignore the question right here.
# 2                            You can ignore all of this.
# 3                         So let's think about this way.
# 4                  That's what this right here tells us.
# ...                                                  ...
# 40150         But I still don't know what this thing is.
# 40151                        And I want to clarify this.
# 40152  And I didn't have to assume this to kind of ge...
# 40153               So in no way is this proof circular.
# 40154  It's my fault because I didn't explain it prop...
#
#                                               th
# 0      นี่คือปัญหาข้อเดิมที่เราทำในวิดีโอที่แล้ว
# 1                        คุณลืมคำถามที่แล้วไปได้
# 2                            คุณทิ้งทั้งหมดนี่ไป
# 3                                ลองคิดแบบนี้กัน
# ...

# %%
qed_df.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/QED_Clean_reform.csv',index = False)

# %%
# tanzil

tanzil_df  = pd.read_csv(tanzil_path)

# %%
tanzil_df
# Out:
#                                                       th  \
# 0         “แน่นอน เราก็จะเป็นบ่าวของอัลลอฮฺผู้ซื่อสัตย์”
# 1      และจงรำลึกถึงขณะที่เราได้เอาคำมั่นสัญญาจากพวกเ...
# 2      ครั้นเมื่อแต่ละฝ่ายได้มองเห็นกัน พวกพ้องของมูซ...
# 3      และบรรดาผู้ที่เมื่อพวกเขาใช้จ่าย พวกเขาก็ไม่สุ...
# 4      และจงรำลึกถึงขณะที่เราได้สัญญาแก่มูซาไว้สี่สิบ...
# ...                                                  ...
# 66577                     พวกเขารู้ในสิ่งที่พวกเจ้ากระทำ
# 66578  แท้จริงสิ่งที่พวกเจ้าถูกสัญญาไว้นั้นเป็นความจร...
# 66579  พวกเขาก็จะไม่ศรัทธามันจนกว่าพวกเขาจะได้เห็นการ...
# 66580  แท้จริงสิ่งที่พวกเจ้าถูกสัญญาไว้นั้นเป็นความจร...
# 66581                       และจากแม่ของเขา และพ่อของเขา
#
#                                                       en  similarity
# 0      Surefy we would have been the bondmen of God s...    0.650001
# 1      And when We took a pledge from you, and raised...    0.650005
# 2      So when the two hosts saw each other, the comp...    0.650008
# ...

# %%
tanzil_df = tanzil_df.drop('similarity', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
columns_titles = ["en","th"]
tanzil_df = tanzil_df.reindex(columns=columns_titles)

# %%
tanzil_df
# Out:
#                                                       en  \
# 0      Surefy we would have been the bondmen of God s...
# 1      And when We took a pledge from you, and raised...
# 2      So when the two hosts saw each other, the comp...
# 3      who in their spending are neither extravagant ...
# 4      And remember We appointed forty nights for Mos...
# ...                                                  ...
# 66577                             They know what you do.
# 66578              indeed what you are promised is true.
# 66579  They will not believe in it until they see the...
# 66580             Indeed, what you are promised is true.
# 66581                And from his mother and his father.
#
#                                                       th
# 0         “แน่นอน เราก็จะเป็นบ่าวของอัลลอฮฺผู้ซื่อสัตย์”
# 1      และจงรำลึกถึงขณะที่เราได้เอาคำมั่นสัญญาจากพวกเ...
# 2      ครั้นเมื่อแต่ละฝ่ายได้มองเห็นกัน พวกพ้องของมูซ...
# ...

# %%
tanzil_df.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/Tanzil_dataset_reform.csv',index = False)

# %%
#Ubuntu

ubuntu_df = pd.read_csv(ubuntu_path)

# %%
ubuntu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3462 entries, 0 to 3461
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   en      3461 non-null   object
#  1   th      3462 non-null   object
# dtypes: object(2)
# memory usage: 54.2+ KB

# %%
ubuntu_df
# Out:
#                                                      en  \
# 0                                   AisleRiot Solitaire
# 1                   Play many different solitaire games
# 2                                       Theme file name
# 3     The name of the file with the graphics for the...
# 4                    Whether or not to show the toolbar
# ...                                                 ...
# 3457                                  Horizontal Layout
# 3458                            Set a horizontal layout
# 3459                                    Vertical Layout
# 3460                              Set a vertical layout
# 3461                       Click to close the side pane
#
#                                     th
# 0                     ถอดไพ่ AisleRiot
# 1               เล่นเกมถอดไพ่สารพัดแบบ
# 2                    ชื่อแฟ้มชุดตกแต่ง
# 3     ชื่อของแฟ้มที่เก็บรูปภาพสำรับไพ่
# 4           จะแสดงแถบเครื่องมือหรือไม่
# ...                                ...
# ...

# %%
#bible

bile_df = pd.read_csv(bible_path)

# %%
bile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72332 entries, 0 to 72331
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  72332 non-null  int64
#  1   th          72332 non-null  object
#  2   en          72332 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
bile_df
# Out:
#        Unnamed: 0                                                 th  \
# 0               0  ['ใน', 'เริ่มแรก', 'นั้น', 'พระเจ้า', 'ทรง', '...
# 1               1  ['แผ่นดิน', 'โลก', 'นั้น', 'ก็', 'ปราศจาก', 'ร...
# 2               3  ['พระเจ้า', 'ทรง', 'เห็น', 'ว่า', 'ความสว่าง',...
# 3               4  ['พระเจ้า', 'ทรง', 'เรียก', 'ความสว่าง', 'นั้น...
# 4               6  ['พระเจ้า', 'ทรง', 'สร้าง', 'พื้น', 'อากาศ', '...
# ...           ...                                                ...
# 72327      124378  ['คน', 'ทั้งหลาย', 'ที่', 'ประพฤติตาม', 'พระ',...
# 72328      124379  ['ด้วยว่า', 'ภาย', 'นอกนั้น', 'มี', 'สุนัข', '...
# 72329      124380  ['"', 'เรา', 'คือ', 'เยซู', 'ผู้ใช้', 'ให้', '...
# 72330      124382  ['ข้าพเจ้า', 'เป็น', 'พยาน', 'แก่', 'ทุกคน', '...
# 72331      124383  ['และ', 'ถ้า', 'ผู้ใด', 'ตัด', 'ข้อความ', 'ออก...
#
#                                                       en
# 0      In the beginning God created the heavens and t...
# ...

# %%
bile_df = bile_df.drop('Unnamed: 0', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
bile_df
# Out:
#                                                       th  \
# 0      ['ใน', 'เริ่มแรก', 'นั้น', 'พระเจ้า', 'ทรง', '...
# 1      ['แผ่นดิน', 'โลก', 'นั้น', 'ก็', 'ปราศจาก', 'ร...
# 2      ['พระเจ้า', 'ทรง', 'เห็น', 'ว่า', 'ความสว่าง',...
# 3      ['พระเจ้า', 'ทรง', 'เรียก', 'ความสว่าง', 'นั้น...
# 4      ['พระเจ้า', 'ทรง', 'สร้าง', 'พื้น', 'อากาศ', '...
# ...                                                  ...
# 72327  ['คน', 'ทั้งหลาย', 'ที่', 'ประพฤติตาม', 'พระ',...
# 72328  ['ด้วยว่า', 'ภาย', 'นอกนั้น', 'มี', 'สุนัข', '...
# 72329  ['"', 'เรา', 'คือ', 'เยซู', 'ผู้ใช้', 'ให้', '...
# 72330  ['ข้าพเจ้า', 'เป็น', 'พยาน', 'แก่', 'ทุกคน', '...
# 72331  ['และ', 'ถ้า', 'ผู้ใด', 'ตัด', 'ข้อความ', 'ออก...
#
#                                                       en
# 0      In the beginning God created the heavens and t...
# 1      Now the earth was formless and empty. Darkness...
# 2      God saw the light, and saw that it was good. G...
# ...

# %%
columns_titles = ["en","th"]
bile_df = bile_df.reindex(columns=columns_titles)

# %%
bile_df
# Out:
#                                                       en  \
# 0      In the beginning God created the heavens and t...
# 1      Now the earth was formless and empty. Darkness...
# 2      God saw the light, and saw that it was good. G...
# 3      God called the light "day," and the darkness h...
# 4      God made the expanse, and divided the waters w...
# ...                                                  ...
# 72327  Blessed are they that do his commandments, tha...
# 72328  For without are dogs, and sorcerers, and whore...
# 72329  I Jesus have sent mine angel to testify unto y...
# 72330  For I testify unto every man that heareth the ...
# 72331  And if any man shall take away from the words ...
#
#                                                       th
# 0      ['ใน', 'เริ่มแรก', 'นั้น', 'พระเจ้า', 'ทรง', '...
# 1      ['แผ่นดิน', 'โลก', 'นั้น', 'ก็', 'ปราศจาก', 'ร...
# 2      ['พระเจ้า', 'ทรง', 'เห็น', 'ว่า', 'ความสว่าง',...
# ...

# %%
def process_bible(my_str):
    l = my_str.replace(" ",'')
    return pd.Series(l)

# %%
bile_df[['th']] = bile_df["th"].apply(process_bible)

# %%
bile_df
# Out:
#                                                       en  \
# 0      In the beginning God created the heavens and t...
# 1      Now the earth was formless and empty. Darkness...
# 2      God saw the light, and saw that it was good. G...
# 3      God called the light "day," and the darkness h...
# 4      God made the expanse, and divided the waters w...
# ...                                                  ...
# 72327  Blessed are they that do his commandments, tha...
# 72328  For without are dogs, and sorcerers, and whore...
# 72329  I Jesus have sent mine angel to testify unto y...
# 72330  For I testify unto every man that heareth the ...
# 72331  And if any man shall take away from the words ...
#
#                                                       th
# 0      ในเริ่มแรกนั้นพระเจ้าทรงเนรมิตสร้างฟ้าและแผ่นด...
# 1      แผ่นดินโลกนั้นก็ปราศจากรูปร่างและว่างเปล่าอยู่...
# 2      พระเจ้าทรงเห็นว่าความสว่างนั้นดีและพระเจ้าทรงแ...
# ...

# %%
bile_df.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/bible_dataset_reform.csv',index = False)

# %%
# jw300

jw300_df = pd.read_csv(jw300_path)

# %%
jw300_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109561 entries, 0 to 109560
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   trg     109561 non-null  object
#  1   src     109561 non-null  object
# dtypes: object(2)
# memory usage: 1.7+ MB

# %%
jw300_df
# Out:
#                                                       trg  \
# 0       “ Sins committed in the dark are seen in Heave...
# 1       IN APRIL 1988 the Church in the Soviet Union r...
# 2       As regards Christianity , the Dark Ages were i...
# 3       The gospel light of Christianity had been , fo...
# 4       In 1871 it was revived in the Second Reich ( G...
# ...                                                   ...
# 109556  What are some of the things we accomplish thro...
# 109557  ( b ) Illustrate why Jehovah appreciates our d...
# 109558  What does Jehovah require from those whose nam...
# 109559  Ask yourself : ‘ Is my complete allegiance to ...
# 109560  Does your lifestyle clearly identify you as on...
#
#                                                       src
# 0       “ บาป ​ ซึ่ง ​ ได้ ​ กระทำ ​ ใน ​ ที่ ​ มืด ​ ...
# 1       เดือน ​ เมษายน 1988 คริสต์ ​ จักร ​ ใน ​ สหภาพ...
# 2       สำหรับ ​ หลัก การ ​ คริสเตียน ยุค ​ มืด ​ เป็น...
# ...

# %%
jw300_df = jw300_df.rename(columns={'trg': 'en', 'src': 'th'})

# %%
jw300_df
# Out:
#                                                        en  \
# 0       “ Sins committed in the dark are seen in Heave...
# 1       IN APRIL 1988 the Church in the Soviet Union r...
# 2       As regards Christianity , the Dark Ages were i...
# 3       The gospel light of Christianity had been , fo...
# 4       In 1871 it was revived in the Second Reich ( G...
# ...                                                   ...
# 109556  What are some of the things we accomplish thro...
# 109557  ( b ) Illustrate why Jehovah appreciates our d...
# 109558  What does Jehovah require from those whose nam...
# 109559  Ask yourself : ‘ Is my complete allegiance to ...
# 109560  Does your lifestyle clearly identify you as on...
#
#                                                        th
# 0       “ บาป ​ ซึ่ง ​ ได้ ​ กระทำ ​ ใน ​ ที่ ​ มืด ​ ...
# 1       เดือน ​ เมษายน 1988 คริสต์ ​ จักร ​ ใน ​ สหภาพ...
# 2       สำหรับ ​ หลัก การ ​ คริสเตียน ยุค ​ มืด ​ เป็น...
# ...

# %%
def process_bible(my_str):
    l = my_str.replace(" ",'')
    l = my_str.replace('\u200b', '')
    return pd.Series(l)

# %%
def process_en(my_str):
    l = my_str.replace('\u200b', '')
    return pd.Series(l)

# %%
jw300_df[['th']] = jw300_df["th"].apply(process_bible)

# %%
jw300_df[['en']] = jw300_df["en"].apply(process_en)

# %%
jw300_df
# Out:
#                                                        en  \
# 0       “ Sins committed in the dark are seen in Heave...
# 1       IN APRIL 1988 the Church in the Soviet Union r...
# 2       As regards Christianity , the Dark Ages were i...
# 3       The gospel light of Christianity had been , fo...
# 4       In 1871 it was revived in the Second Reich ( G...
# ...                                                   ...
# 109556  What are some of the things we accomplish thro...
# 109557  ( b ) Illustrate why Jehovah appreciates our d...
# 109558  What does Jehovah require from those whose nam...
# 109559  Ask yourself : ‘ Is my complete allegiance to ...
# 109560  Does your lifestyle clearly identify you as on...
#
#                                                        th
# 0       “บาปซึ่งได้กระทำในที่มืดปรากฏดุจเปลวเพลิงในสวร...
# 1       เดือนเมษายน1988คริสต์จักรในสหภาพโซเวียตพากันชื...
# 2       สำหรับหลักการคริสเตียนยุคมืดเป็นยุคแห่งความมืด...
# ...

# %%
jw300_df.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/jw300_reform.csv',index = False)

# %%
# opensub

sub_df = pd.read_csv(sub_path)

# %%
sub_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2597445 entries, 0 to 2597444
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   en          object
#  1   th          object
#  2   sim         float64
#  3   encat       object
#  4   thcat       object
#  5   en_len      int64
#  6   th_len      int64
#  7   proportion  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 158.5+ MB

# %%
sub_df.sample(10)
# Out:
#                                                         en  \
# 197277                                    I saw it coming.
# 11722                     Please! come on! Omnis immundus.
# 611158          Guy drives a fiesta, lives in the rectory.
# 325308                            Carla Jean, how are you?
# 1452945  I believe this is the fake one you are looking...
# 175464                                 It's just for show.
# 2265594                                         Know what?
# 2400340  Our Russian partners are hiding accounts from us.
# 53243                                        No, I'm good.
# 52082                                            Aw, hell.
#
#                                                        th     sim  \
# 197277                                   แม่เคยเจอมันแล้ว  0.5690
# 11722             ได้โปรด ไม่เอาน่า ดูสิ บางอย่างมันผิดนะ  0.4429
# 611158                ขับรถเฟียสต้า พักที่บ้านพักของโบสถ์  0.6940
# ...

# %%
sub_df = sub_df.drop('sim', 1)
sub_df = sub_df.drop('encat', 1)
sub_df = sub_df.drop('thcat', 1)
sub_df = sub_df.drop('en_len', 1)
sub_df = sub_df.drop('th_len', 1)
sub_df = sub_df.drop('proportion', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.
# ...

# %%
sub_df.sample(10)
# Out:
#                                                         en  \
# 1130344                   Never show your face here again.
# 1065626                                           Mmm-hmm.
# 1233143                                               Ohh!
# 893099                                 Permission granted.
# 1491401             I told you, I'll figure something out.
# 2175410         Is this the loud machine with the magnets?
# 880742                                 That's my tracking.
# 1116971           I swear on my vow to the Nameless Order!
# 1675854         We don't have to fit 80 years into a week.
# 182174   It has to be turned upside down, stepped on, a...
#
#                                                         th
# 1130344                       อย่าได้มาเสนอหน้าที่นี่อีกนะ
# 1065626                                            อืม ได้
# 1233143                                               อ้าา
# 893099                                     คำขออนุญาติแล้ว
# ...

# %%
sub_df.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/sub_finallycleaned_reform.csv',index = False)

# %%
# reconfig invalid content
sub_df = pd.read_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/sub_finallycleaned_reform.csv')

# %%
sub_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2597445 entries, 0 to 2597444
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   en      object
#  1   th      object
# dtypes: object(2)
# memory usage: 39.6+ MB

# %%
sub_df.drop(sub_df.index[[23433,34488,68647,123120,177350,292469,403657,489931,449,5737,12259,21814,23596,23934,24677,28380]], inplace=True)

# %%
sub_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2597429 entries, 0 to 2597444
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   en      object
#  1   th      object
# dtypes: object(2)
# memory usage: 59.5+ MB

# %%
sub_df.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/sub_finallycleaned_reform_edit.csv',index = False)

# %%
# reconfig invalid content again
sub_df = pd.read_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/sub_finallycleaned_reform_edit.csv')

# %%
sub_df.drop(sub_df.index[[29388,35986,37219,50236,61490,63296,68024,84640,102176,102561,104183,105680,120038,120543,125284,128189,129492,137370,142620,149438,252879,381741,621309,637386,759882,771066]], inplace=True)

# %%
sub_df.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/sub_finallycleaned_reform_edit.csv',index = False)

# %% [markdown]
# # SCB datset

# %%
scb_train = pd.read_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/scb_mt_enth_2020_train.csv')
scb_val = pd.read_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/scb_mt_enth_2020_validation.csv')
scb_test = pd.read_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/scb_mt_enth_2020_test.csv')

# %%
scb_train = scb_train.drop(['Unnamed: 0','subdataset'], 1)
scb_val = scb_val.drop(['Unnamed: 0','subdataset'], 1)
scb_test = scb_test.drop(['Unnamed: 0','subdataset'], 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
scb_train.head()
# Out:
#                                                   en  \
# 0  FAR LEFT: Indonesian National Police Chief Tit...
# 1  (Pictured: A rocket believed to be a Hwasong m...
# 2  (Pictured: Left to right, Australia's Defence ...
# 3  (Pictured: A man watches the live-stream trans...
# 4  (Pictured: Rohingya Muslims, who left Burma fo...
#
#                                                   th
# 0  (ซ้ายสุด) นายติโต คาร์นาเวียน ผู้บัญชาการตํารว...
# 1  (ภาพ: จรวดซึ่งเชื่อว่าเป็นขีปนาวุธฮวาซองเช่นเด...
# 2  (ภาพ: จากซ้ายไปขวา นางมารีส เพย์น รัฐมนตรีว่าก...
# 3  (ภาพ: ชายคนหนึ่งชมการแพร่ภาพออกอากาศสดการปล่อย...
# 4  (ภาพ: ชาวมุสลิมโรฮีนจาซึ่งเดินทางออกจากพม่าไปย...

# %%
scb_val.head()
# Out:
#                                                   en  \
# 0     I have many memories that cannot be recovered.
# 1  I loved the look of this item but when we actu...
# 2  I've never had a bad experience with buying fr...
# 3  You'd be better off making a bottle out of emp...
# 4          Beauty and the porn close-up photo diskus
#
#                                                   th
# 0  ฉันมีความทรงจําที่เก็บไว้หลายอย่างมากที่กู้คืน...
# 1  ฉันชอบหน้าตาของไอเท็มนี้ แต่เมื่อเราต้องใช้มัน...
# 2  ฉันไม่เคยมีประสบการณ์ที่เลวร้ายกับการซื้อจาก A...
# 3               คุณควรใช้มันเป็นกล่องใส่น้ําผลไม้แทน
# 4                ความงามและหนังโป๊ใกล้ขึ้นรูป diskus

# %%
scb_test.head()
# Out:
#                                                   en  \
# 0                 These are good for using at night.
# 1                                    It's Max Smith.
# 2  please bring your labcoat today.give me a miss...
# 3                   Scotch-Brite XN002033480 Wet Mop
# 4  Coupon Detail 500 units for coupons for any jo...
#
#                                                   th
# 0                  ของพวกนี้ดีต่อการใช้งานตอนกลางคืน
# 1                                     แม็กซ์ สมิธค่ะ
# 2  ช่วยเอาเสื้อโค๊ตห้องแลปของเธอมาทีนะวันนี้ มิสค...
# 3  ม็อบเปียกซับน้ําดีเยี่ยม สก๊อตช์-ไบรต์ XN00203...
# 4  500 หน่วยสําหรับคูปองสําหรับการสั่งซื้อ joybuy...

# %%
scb_train.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/scb_mt_enth_2020_train_reform.csv', index = False)
scb_val.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/scb_mt_enth_2020_validation_reform.csv',index = False)
scb_test.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/scb_mt_enth_2020_test_reform.csv' , index = False)

# %%
scb_full = pd.concat([scb_train, scb_val , scb_test], axis=0)

# %%
scb_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801402 entries, 0 to 801401
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   en      801402 non-null  object
#  1   th      801402 non-null  object
# dtypes: object(2)
# memory usage: 12.2+ MB

# %%
scb_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1001752 entries, 0 to 100176
# Data columns (total 2 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   en      1001752 non-null  object
#  1   th      1001752 non-null  object
# dtypes: object(2)
# memory usage: 22.9+ MB

# %%
scb_full = scb_full.reset_index()

# %%
scb_full = scb_full.drop(['index'], 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
scb_full.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/scb_mt_enth_2020_full.csv' , index = False)

# %% [markdown]
# # OPUS

# %%
opus_train_en = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/opus.en-th-train.en'
opus_train_th = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/opus.en-th-train.th'

opus_val_en = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/opus.en-th-dev.en'
opus_val_th = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/opus.en-th-dev.th'

opus_test_en = '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/opus.en-th-test.en'
opus_test_th =  '/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/opus.en-th-test.th'

# %%
def file2liststring(filepath):
  with open(filepath, mode='rb') as file: 
      stringlist = file.readlines()
  return [re.sub('[\r\n]', '', text.decode('utf-8')) for text in stringlist]

# %%
opus_en_train = file2liststring(opus_train_en)
opus_th_train = file2liststring(opus_train_th)

# %%
opus_enth_dict = {
              'en' : opus_en_train,
              'th' : opus_th_train
            }

# %%
opus_enth_train_df =  pd.DataFrame(opus_enth_dict)

# %%
opus_enth_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   en      1000000 non-null  object
#  1   th      1000000 non-null  object
# dtypes: object(2)
# memory usage: 15.3+ MB

# %%
opus_enth_train_df.tail()
# Out:
#                                                    en  \
# 999995                                  Miss gibbons?
# 999996  If you do that, we'll never bother you again.
# 999997                                    old chap...
# 999998                Right, Wednesdays, 7:30, Great,
# 999999                                   I'm popular.
#
#                                                       th
# 999995                                      คุณกิบบอนส์?
# 999996  ถ้าคุณพ่อทำตามนั้น เราก็จะไม่มากวนใจคุณพ่ออีกเลย
# 999997                                         ตาเฒ่า...
# 999998                         ครับ ทุกวันพุธ ตอน 19.30น
# 999999                                     ที่นี้ ฉันฮอท

# %%
opus_enth_train_df.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/opus_enth_train.csv' , index = False)

# %%
opus_en_val = file2liststring(opus_val_en)
opus_th_val = file2liststring(opus_val_th)

# %%
opus_enth_dict_val = {
              'en' : opus_en_val,
              'th' : opus_th_val
            }

# %%
opus_enth_val_df =  pd.DataFrame(opus_enth_dict_val)

# %%
opus_enth_val_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   en      2000 non-null   object
#  1   th      2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB

# %%
opus_enth_val_df.tail()
# Out:
#                                                  en  \
# 1995                   I wonder where she got this.
# 1996                        We must close the gate.
# 1997            You said I was free to come and go.
# 1998               Well, we're on pins and needles.
# 1999  Kjetil, we have to get up. We have to get up.
#
#                                                th
# 1995             ฉันสงสัยจัง ว่าเธอได้มันมาจากไหน
# 1996                           เราจะต้องปิดประตู.
# 1997  คุณพูดเองว่าฉันมีสิทธิ์ที่จะไปไหนมาไหนก็ได้
# 1998                               เหน็บกินแล้วนะ
# 1999                               เชทิล ตื่นเถอะ

# %%
opus_enth_val_df.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/opus_enth_val.csv' , index = False)

# %%
opus_en_test = file2liststring(opus_test_en)
opus_th_test = file2liststring(opus_test_th)

# %%
opus_enth_dict_test = {
              'en' : opus_en_test,
              'th' : opus_th_test
            }

# %%
opus_enth_test_df =  pd.DataFrame(opus_enth_dict_test)

# %%
opus_enth_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   en      2000 non-null   object
#  1   th      2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB

# %%
opus_enth_test_df.tail()
# Out:
#                                                      en  \
# 1995                           Music by Yuriko Nakamura
# 1996                 Yo, these people taking forever...
# 1997          I tell you what... why don't you ask her?
# 1998                         She hasn't said "yes" yet.
# 1999  He's always looking for someone to trust, but ...
#
#                                                      th
# 1995                          Music โดย Yuriko Nakamura
# 1996                            โย่ คนพวกนี้น่ารักจริงๆ
# 1997              พ่อจะบอกอะไรให้ ทำไมลูกไม่ถามแม่ดูล่ะ
# 1998                         เธอยังไม่ได้ตอบ "ตกลง" ค่ะ
# 1999  เขามักมองหาใครสักคนที่เขาเชื่่อใจเสมอ แต่ความห...

# %%
opus_enth_test_df.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/opus_enth_test.csv' , index = False)

# %%
opus_full = pd.concat([opus_enth_train_df, opus_enth_val_df , opus_enth_test_df], axis=0)

# %%
opus_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1004000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   en      1004000 non-null  object
#  1   th      1004000 non-null  object
# dtypes: object(2)
# memory usage: 23.0+ MB

# %%
opus_full.to_csv('/content/drive/MyDrive/NMT Hackathon/Dataset/TrainSet/Clean/opus_full.csv' , index = False)
